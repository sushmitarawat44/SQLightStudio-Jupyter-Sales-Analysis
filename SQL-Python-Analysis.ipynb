# %%
import pandas as pd 
import matplotlib.pyplot as plt
import sqlite3
#connect databse
conn = sqlite3.connect(r"C:\Users\sushmita\OneDrive\Desktop\sales_data.db")

# %%
# Corrected query
query = """
SELECT Product, SUM(Quantity * Price) AS revenue
FROM sales
GROUP BY Product
"""

# %%
df = pd.read_sql_query(query, conn)
conn.close()

# %%
print(df)
print(df.columns)
# Out:
#                 Product  revenue
# 0      Alpine Honey Jar    17.40
# 1     Basil Oat Cookies    12.00
# 2          Crimson Kiwi    10.15
# 3     Dried Dragonfruit     4.60
# 4   Glacier Water 500ml     7.50
# 5      Lemon Quinoa Mix     8.55
# 6  Midnight Coffee Pods    49.60
# 7     Sea Salt Crackers    12.40
# 8     Smoked Tofu Block     7.80
# 9          Velvet Mango     5.50
# Index(['Product', 'revenue'], dtype='object')

# %%
df.plot(kind='bar', x='Product', y='revenue', legend=False, color='skyblue')
plt.title("Revenue by Product")
plt.xlabel("Product")
plt.ylabel("Revenue")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.savefig("sales_chart.png", dpi=300)
